# %%
import pandas as pd
import numpy as np
d1=pd.read_csv("week1.csv")
print(d1)
print("\n\nSummary Statistics :\n")
print(d1.describe(),"\n\n")
print(d1.loc[2],"\n\n")
print(d1.loc[2,'CGPA'],"\n\n\n")
print(d1.info(),"\n")
print("\nMean and Standard Deviation of data :\n")
print(d1.describe().loc[['mean','std']])
# Out:
#     Roll No.          Name Section  CGPA  Semester Percentage
# 0        101  Aarav Sharma       A   8.5         4     80.75%
# 1        102  Ishani Gupta       B   9.2         4     87.40%
# 2        103     Rohan Das       A   7.8         4     74.10%
# 3        104   Priya Verma       C   8.9         4     84.55%
# 4        105   Kabir Singh       B   6.5         4     61.75%
# 5        106    Meera Iyer       A   9.5         4     90.25%
# 6        107    Arjun Nair       C   7.2         4     68.40%
# 7        108    Diya Reddy       B   8.1         4     76.95%
# 8        109  Vivaan Malik       A   8.8         4     83.60%
# 9        110    Ananya Jha       C   9.0         4     85.50%
# 10       111    Sahil Khan       B   7.5         4     71.25%
# 11       112   Tara Bansal       A   8.3         4     78.85%
# 12       113     Yash Goel       C   6.8         4     64.60%
# 13       114   Sana Sheikh       B   9.1         4     86.45%
# ...

# %%
import numpy as np
import pandas as pd
data=pd.read_excel("week1.xlsx")
print(data,"\n\n\n")
print(data.loc[3],"\n")
print(data.loc[3,'CGPA'],"\n\n")
print("Summary Statistics :\n")
print(data.describe(),"\n\n\n")
print(data.info())
# Out:
#     Roll No.          Name Section  CGPA  Semester  Percentage
# 0        101  Aarav Sharma       A   8.5         4      0.8075
# 1        102  Ishani Gupta       B   9.2         4      0.8740
# 2        103     Rohan Das       A   7.8         4      0.7410
# 3        104   Priya Verma       C   8.9         4      0.8455
# 4        105   Kabir Singh       B   6.5         4      0.6175
# 5        106    Meera Iyer       A   9.5         4      0.9025
# 6        107    Arjun Nair       C   7.2         4      0.6840
# 7        108    Diya Reddy       B   8.1         4      0.7695
# 8        109  Vivaan Malik       A   8.8         4      0.8360
# 9        110    Ananya Jha       C   9.0         4      0.8550
# 10       111    Sahil Khan       B   7.5         4      0.7125
# 11       112   Tara Bansal       A   8.3         4      0.7885
# 12       113     Yash Goel       C   6.8         4      0.6460
# 13       114   Sana Sheikh       B   9.1         4      0.8645
# ...

# %%
import pandas as pd
import numpy as np
d=pd.read_json("week1.json")
print(d,"\n\n\n")
print(d.loc[1],"\n\n")
print("Summary Statistics :\n")
print(d.describe(),"\n\n")
print(d.info())
# Out:
#    Roll_no          Name Section  CGPA  Semester  Percentage
# 0      101  Aarav Sharma       A   8.5         4       80.75
# 1      102  Ishani Gupta       B   9.2         4       87.40
# 2      103     Rohan Das       A   7.8         4       74.10
# 3      104   Priya Verma       C   8.9         4       84.55
# 4      105   Kabir Singh       B   6.5         4       61.75
# 5      106    Meera Iyer       A   9.5         4       90.25
# 6      107    Arjun Nair       C   7.2         4       68.40
# 7      108    Diya Reddy       B   8.1         4       76.95
# 8      109  Vivaan Malik       A   8.8         4       83.60
# 9      110    Ananya Jha       C   9.0         4       85.50
#
#
#
# Roll_no                102
# Name          Ishani Gupta
# Section                  B
# CGPA                   9.2
# Semester                 4
# Percentage            87.4
# Name: 1, dtype: object
#
#
# Summary Statistics :
#
#          Roll_no       CGPA  Semester  Percentage
# ...

# %%
text = open("week1.txt")
d3 = text.read()
print (d3)
# Out:
# Roll_no, Name, Section, CGPA, Semester, Percentage
# 101, Aarav Sharma, A, 8.5, 4, 80.75
# 102, Ishani Gupta, B, 9.2, 4, 87.40
# 103, Rohan Das, A, 7.8, 4, 74.10
# 104, Priya Verma, C, 8.9, 4, 84.55
# 105, Kabir Singh, B, 6.5, 4, 61.75
# 106, Meera Iyer, A, 9.5, 4, 90.25
# 107, Arjun Nair, C, 7.2, 4, 68.40
# 108, Diya Reddy, B, 8.1, 4, 76.95
# 109, Vivaan Malik, A, 8.8, 4, 83.60
# 110, Ananya Jha, C, 9.0, 4, 85.50
# 111, Sahil Khan, B, 7.5, 4, 71.25
# 112, Tara Bansal, A, 8.3, 4, 78.85
# 113, Yash Goel, C, 6.8, 4, 64.60
# 114, Sana Sheikh, B, 9.1, 4, 86.45
# 115, Rahul Bose, A, 7.9, 4, 75.05
# 116, Kavya Menon, C, 8.4, 4, 79.80
# 117, Rishi Pal, B, 7.3, 4, 69.35
# 118, Neha Kapoor, A, 9.7, 4, 92.15
# 119, Aman Joshi, C, 6.9, 4, 65.55
# 120, Zoya Ali, B, 8.6, 4, 81.70

# %%
import zipfile
import pandas as pd
data=zipfile.ZipFile("sample.zip",'r')
data1=data.read("sample/text.txt")
print(data1)
# Out:
# b'this is a sample text'

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
data=pd.read_csv("week1.csv")
#plt.hist(data['Percentage'],color='green')
#plt.show()
x=np.array(data['Roll No.'])
y=np.array(data['Percentage'])
plt.bar(x,y,color='blue')
plt.xlabel("Roll.no of the Students")
plt.ylabel("Percentage")
plt.title("Roll.no vs Percentage of the Students")
plt.show()
